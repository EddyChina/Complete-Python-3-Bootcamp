# %% [markdown]
# <a href="https://colab.research.google.com/github/EddyChina/Complete-Python-3-Bootcamp/blob/master/FanEddyA0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('''
      Welcome to Laurentian University!
      Bienvenue à l'Université Laurentienne!
      ''')
# Out:
#       Welcome to Laurentian University!
#       Bienvenue à l'Université Laurentienne!
